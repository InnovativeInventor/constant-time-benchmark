# %%
import numpy as np
import seaborn as sns

# %%
dataset_0 = np.array([])
with open("golang-subtle/output-test0", "r") as f:
    for count, each_line in enumerate(f):
        if count % 2 == 1:
            assert str(each_line).rstrip() == "0"
            continue
        try:
            processed = int(each_line.rstrip()[:3])
            dataset_0 = np.append(dataset_0, processed)
        except:
            pass

print(sns.distplot(dataset_0, bins=20, kde=False, rug=False))
print("Mean", np.mean(dataset_0))
print("Median", np.median(dataset_0))
print("Min", np.min(dataset_0))
print("Std", np.std(dataset_0))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Mean 179.13993677555322
# Median 172.0
# Min 102.0
# Std 46.70515679933401

# %%
print(sns.kdeplot(dataset_0, shade=True))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dataset_1 = np.array([])
with open("golang-subtle/output-test1", "r") as f:
    for count, each_line in enumerate(f):
        if count % 2 == 1:
            assert str(each_line).rstrip() == "1"
            continue
        try:
#             print(each_line)
            processed = int(each_line.rstrip()[:3])
            dataset_1 = np.append(dataset_1, processed)
        except:
            pass

print(sns.distplot(dataset_1, bins=20, kde=False, rug=False))
print("Mean", np.mean(dataset_1))
print("Median", np.median(dataset_1))
print("Min", np.min(dataset_1))
print("Std", np.std(dataset_1))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Mean 181.5736945698738
# Median 175.0
# Min 102.0
# Std 47.23551601113846

# %%
print(sns.kdeplot(dataset_0, shade=True))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
